# %% [markdown]
# ### RANDOM PHASE ANGLES

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
angs = np.random.rand(100) * 2 * np.pi
for i in angs:
    plt.plot([0, np.cos(i)], [0, np.sin(i)])

plt.axis("square")
plt.axis([-1, 1, -1, 1])
plt.axis("off")
plt.show()

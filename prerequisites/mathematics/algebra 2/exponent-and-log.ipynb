# %% [markdown]
# ### NATURAL EXPONENT AND ALGORITHM

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
x = np.linspace(-3, 3, 99)

plt.plot(x, np.exp(x))
plt.xlabel("x")
plt.ylabel("$e^x$")
plt.show()

plt.plot(x, np.log(x))
plt.xlabel("x")
plt.ylabel("log(x)")

plt.show()
# Out:
# /tmp/ipykernel_66772/1893186287.py:8: RuntimeWarning: divide by zero encountered in log
#   plt.plot(x, np.log(x))
# /tmp/ipykernel_66772/1893186287.py:8: RuntimeWarning: invalid value encountered in log
#   plt.plot(x, np.log(x))

# %%
x = np.linspace(0.0001, 10, 10)
y1 = np.log(np.exp(x))
y2 = np.exp(np.log(x))

plt.plot(x, y1, label="$\\log(e^x)$")
plt.plot(x, y2, "o", label="$e^{\\log (x)}$")
plt.axis("square")
plt.legend()

plt.show()

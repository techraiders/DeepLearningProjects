# %%
import matplotlib.pyplot as plt
import numpy as np

x = np.random.rand(50)
y = np.random.rand(50)

plt.scatter(x, y, s=100, color='gray', alpha=0.5)
plt.scatter(x[10], y[10], s=300, color='red', edgecolors='black', label='Highlighted Point')
plt.legend()
plt.show()

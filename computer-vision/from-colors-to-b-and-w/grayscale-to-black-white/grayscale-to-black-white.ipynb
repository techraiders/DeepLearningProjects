# %%
# Let's work with the play space picture

import numpy as np
import matplotlib.pyplot as plt
import os, sys
# %config InlicneBackend.figure_formats = 'retina'
from matplotlib import rcParams

# Get the absolute path to the parent directory (project_root)
parent_dir = os.path.relpath('../../common/util')

# Add parent directory to sys.path if not already added
if parent_dir not in sys.path:
    sys.path.append(parent_dir)

# Now you can import your module from the parent directory
from ec_cv import adapt_PNG, grayscale_to_BW

rcParams['figure.figsize'] = 20,8

toys = adapt_PNG(plt.imread('../../common/images/playspace.png'))
toys_wgt = np.dot(toys[...,:3], [0.299, 0.587, 0.114])
plt.axis("off")
plt.imshow(toys_wgt, cmap='gray')

# %%
# Let's turn each pixel to total black or total white.
# We'll use the grayscale_to_BW() function from EC_CV

rcParams['figure.figsize'] = 20,8


toys_BW = grayscale_to_BW(toys_wgt, 127)
plt.imshow(toys_BW, cmap='gray')

# %%
# Let's see a historgram of the grayscale image
rcParams['figure.figsize'] = (14,8)
plt.hist(toys_wgt.ravel(), 256, [0,255])
plt.title('Histogram')
plt.xticks(np.arange(0, 255, 10))
plt.show()
# Out:
# /tmp/ipykernel_40938/1793696325.py:3: MatplotlibDeprecationWarning: Passing the range parameter of hist() positionally is deprecated since Matplotlib 3.10; the parameter will become keyword-only in 3.12.
#   plt.hist(toys_wgt.ravel(), 256, [0,255])

# %%
# Now, let's create a new black and white image with a threshold of 115
rcParams['figure.figsize'] = (20,8)

toys_BW2 = grayscale_to_BW(toys_wgt, 115)

fig, ax = plt.subplots(1,2)
ax[0].imshow(toys_BW, cmap='gray')
ax[1].imshow(toys_BW2, cmap='gray')

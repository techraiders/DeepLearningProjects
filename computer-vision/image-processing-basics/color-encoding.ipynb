# %% [markdown]
# ## Color Encoding
#
# 1. Color may be encoded in a variety of ways like RGB, RGBA, CMYK, OR HSL. We'll use RGB encoding, where each pixel is represented as a vector with 3 channels: Red, Green and Blue.
#
# 2. RGB is usually encoded as a 24-bit bitmap, meaning that each pixel takes up 24 bits, or 3 bytes.
#
# 3. Each byte represents a color channel, so every value must be an unsigned number between 0 and 255, where 0 means 0% intensity of its color, and 255 means 100% intensity.
#
# Let's play with some colors.

# %%
# First, let's create a simple 3x3 image
import numpy as np
import matplotlib.pyplot as plt
# %config InlineBackend.figure_formats = 'retina'

img = np.array([
    [ [255, 0, 0], [0, 255, 0], [0, 0, 255] ],
    [ [0, 255, 255], [255, 0, 255], [255, 255, 0] ],
    [ [0, 0, 0], [255, 255, 255], [127, 127, 127] ]
])

plt.axis("off")
plt.imshow(img)

# %%
# Let's change the lower left (i.e. row 2, col 0) pixel from back to orange

img[2,0,0] = 255 # Assign 100% to red
img[2,0,1] = 200 # Assign about 80% to green

plt.imshow(img[2:,:1]) # Show pixel at row 2 and column 0

# %%
# Let's display the whole image
plt.imshow(img)
